# %%
import speech_recognition as sr
import pyttsx3
import webbrowser

# Initialize Text-to-Speech engine
engine = pyttsx3.init()

# Function to speak text
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to listen to user input
def listen():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
    
    try:
        print("Recognizing...")
        query = r.recognize_google(audio)
        print("You said:", query)
        return query
    except sr.UnknownValueError:
        print("Sorry, I didn't understand.")
        return ""
    except sr.RequestError as e:
        print("Could not request results; {0}".format(e))
        return ""

# Say "Hello sir"
speak("Hello Samir sir I am your assistant")

# Listen for response
ste="l"
while ste.lower()=="l":
    response = listen()
    if response.lower()=="hello":
        break
if response.lower() == "hello":
    speak("How may I help you?")
    query = listen()

    if query:
        # Perform Google search
        search_url = "https://www.google.com/search?q=" + query.replace(" ", "+")
        webbrowser.open(search_url)
        speak("opening the google chrome")
        speak("Here are the search results for " + query)
        
        # Ask if there's anything else the user wants
        speak("Anything else, Samir sir?")
        next_query = listen()
        
        while next_query.lower() != "no":
            if next_query.lower() == "yes brother":
                speak("What else can I search for you?")
                query = listen()
                
                if query:
                    # Perform Google search
                    search_url = "https://www.google.com/search?q=" + query.replace(" ", "+")
                    print(query.replace(" ", "+"))
                    webbrowser.open(search_url)
                    speak("opening Google sir")
                    speak("Here are the search results for " + query)
                    
                    # Ask if there's anything else the user wants
                    speak("Anything else, sir?")
                    next_query = listen()
                else:
                    speak("Sorry, I didn't catch that. Anything else, sir?")
                    next_query = listen()
            else:
                speak("Sorry, I didn't catch that. Anything else, sir?")
                next_query = listen()
        
        speak("Goodbye sir, have a nice day!")
# Out:
# Listening...
# Recognizing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 39
#      37 ste="l"
#      38 while ste.lower()=="l":
# ---> 39     response = listen()
#      40     if response.lower()=="hello":
#      41         break
#
# Cell In[1], line 23, in listen()
#      21 try:
#      22     print("Recognizing...")
# ---> 23     query = r.recognize_google(audio)
#      24     print("You said:", query)
#      25     return query
#
# File c:\Users\Samee\anaconda3\Lib\site-packages\speech_recognition\recognizers\google.py:244, in recognize_legacy(recognizer, audio_data, key, language, pfilter, show_all, with_confidence)
#     239 request_builder = create_request_builder(
#     240     key=key, language=language, filter_level=pfilter
#     241 )
#     242 request = request_builder.build(audio_data)
# --> 244 response_text = obtain_transcription(
#     245     request, timeout=recognizer.operation_timeout
#     246 )
#     248 output_parser = OutputParser(
#     249     show_all=show_all, with_confidence=with_confidence
#     250 )
#     251 return output_parser.parse(response_text)
#
# File c:\Users\Samee\anaconda3\Lib\site-packages\speech_recognition\recognizers\google.py:205, in obtain_transcription(request, timeout)
#     203 def obtain_transcription(request: Request, timeout: int) -> str:
#     204     try:
# --> 205         response = urlopen(request, timeout=timeout)
#     206     except HTTPError as e:
#     207         raise RequestError("recognition request failed: {}".format(e.reason))
#
# File c:\Users\Samee\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\Samee\anaconda3\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\Samee\anaconda3\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\Samee\anaconda3\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\Samee\anaconda3\Lib\urllib\request.py:1377, in HTTPHandler.http_open(self, req)
#    1376 def http_open(self, req):
# -> 1377     return self.do_open(http.client.HTTPConnection, req)
#
# File c:\Users\Samee\anaconda3\Lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File c:\Users\Samee\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\Samee\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Samee\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Samee\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
